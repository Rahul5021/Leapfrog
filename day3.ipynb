# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tested.csv")

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 308         1200         0       1
# 21           913         0       3
# 380         1272         0       3
# 325         1217         0       3
# 131         1023         0       1
# 206         1098         1       3
# 388         1280         0       3
# 130         1022         0       3
# 119         1011         1       2
# 13           905         0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 308                       Hays, Mr. Charles Melville    male  55.0      1
# 21                         Olsen, Master. Artur Karl    male   9.0      0
# 380                            O'Connor, Mr. Patrick    male   NaN      0
# 325                                   Assam, Mr. Ali    male  23.0      0
# 131                        Gracie, Col. Archibald IV    male  53.0      0
# 206                         McGowan, Miss. Katherine  female  35.0      0
# ...

# %%
tips = pd.read_csv("tips.csv")

# %%
tips.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 159       16.49  2.00    Male     No   Sun  Dinner     4
# 148        9.78  1.73    Male     No  Thur   Lunch     2
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 180       34.65  3.68    Male    Yes   Sun  Dinner     4
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 36        16.31  2.00    Male     No   Sat  Dinner     3

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ### scatterplot to show the distribution of data among two or more variables

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'])
#for multivariate we can use hue, size and style parameters
sns.scatterplot(data=tips,x=tips['total_bill'],y=tips['tip'],hue=tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### barplot

# %%
# df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#sns.barplot(x=df['Pclass'],y=df['Age'])
#for multivariate use hue
sns.barplot(x=df['Pclass'],y=df['Age'],hue=df['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ### boxplot is mainly used to detect the outlier

# %%
sns.boxplot(x=df['Sex'],y=df['Age'])
#for multivariate use hue
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>
